# %% [markdown]
# <a href="https://colab.research.google.com/github/PreethiBoominathan686/g-colab/blob/main/ex_1_banking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include <iostream>
using namespace std;

int main() {

    string username;
    long long accountNumber;
    int choice;
    float balance = 0, amount;
    cout << "Enter Username: ";
    cin >> username;

    cout << "Enter Account Number: ";
    cin >> accountNumber;
    cout << "\n------ BANK MENU ------" << endl;
    cout << "1. Deposit Money" << endl;
    cout << "2. Withdraw Money" << endl;
    cout << "3. Check Balance" << endl;
    cout << "Enter your choice: ";
    cin >> choice;

    switch(choice) {

        case 1:
            cout << "Enter amount to deposit: ";
            cin >> amount;
            balance = balance + amount;
            cout << "Amount Deposited Successfully!" << endl;
            cout << "Current Balance: " << balance << endl;
            break;

        case 2:
            cout << "Enter amount to withdraw: ";
            cin >> amount;

            if(amount <= balance) {
                balance = balance - amount;
                cout << "Amount Withdrawn Successfully!" << endl;
                cout << "Current Balance: " << balance << endl;
            }
            else {
                cout << "Insufficient Balance!" << endl;
            }
            break;

        case 3:
            cout << "Your Current Balance is: " << balance << endl;
            break;

        default:
            cout << "Invalid Choice!" << endl;
    }

    return 0;
}
